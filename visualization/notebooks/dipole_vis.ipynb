# %%
import json
import numpy as np
import py3Dmol

# %%
def read_xyz(filename):
    atoms = []

    with open(filename, "r") as f:
        lines = f.readlines()

    num_atoms = int(lines[0].strip())

    for line in lines[2:2 + num_atoms]:
        parts = line.split()
        if len(parts) < 4:
            continue

        symbol = parts[0]
        x = float(parts[1])
        y = float(parts[2])
        z = float(parts[3])

        atoms.append({
            "elem": symbol,
            "x": x,
            "y": y,
            "z": z
        })

    return atoms

# %%
def show_dipole(dipole_vector, dipole_magnitude, xyz, scale=100, output_file="molecule_dipole.html"):
    
    # Create viewer
    viewer = py3Dmol.view(width=700, height=500)
    viewer.addModel(xyz, "xyz")

    viewer.setStyle({
        "stick": {"radius": 0.15},
        "sphere": {"scale": 0.3}
    })

    # Dipole visualization
    origin = np.array([0.0, 0.0, 0.0])
    # scale = 100.0  # visual scaling factor for dipole length
    # end = origin + scale * dipole_vector
    end = origin + np.linalg.norm(dipole_vector) * scale

    viewer.addArrow({
        "start": {
            "x": float(origin[0]),
            "y": float(origin[1]),
            "z": float(origin[2]),
        },
        "end": {
            "x": float(end[0]),
            "y": float(end[1]),
            "z": float(end[2]),
        },
        "radius": 0.08,
        "color": "red",
        "mid": 0.7
    })

    # Label showing magnitude
    viewer.addLabel(
        f"|μ| = {dipole_magnitude:.3f} D",
        {
            "position": {
                "x": float(end[0]+1*scale),
                "y": float(end[1]+1*scale),
                "z": float(end[2]+1*scale),
            },
            "backgroundColor": "white",
            "fontColor": "black"
        }
    )

    

    viewer.setBackgroundColor("0xeeeeee")
    viewer.zoomTo()
    viewer.spin(True)



    viewer.show()

    # output_file = f"visualization/output/{output_file}_dipole.html"
    html = viewer._make_html()

    with open(f"visualization/output/dipole/{output_file}_dipole.html", "w") as f:
        f.write(html)

# %%
from pathlib import Path

def list_files_no_ext(directory):
    return [p.stem for p in Path(directory).iterdir() if p.is_file()]

files = list_files_no_ext("input/")
print(files)
# Out:
# ['formaldehyde', 'hcl', 'methanol', 'h2o', 'acetaldehyde', 'nh3', 'h2']

# %%
for file in files:
    atoms = read_xyz(f"input/{file}.xyz")
    dipole_file = f"visualization/dipoles/{file}_dipole.json"

    xyz = f"{len(atoms)}\nfrom xyz file\n"
    for a in atoms:
        xyz += f"{a['elem']} {a['x']} {a['y']} {a['z']}\n"

    with open(dipole_file, "r") as f:
        data = json.load(f)

    mu = data["mu"]
    dipole_vector = np.array([mu["x"], mu["y"], mu["z"]])

    show_dipole(dipole_vector, data["magnitude"], xyz, scale=1, output_file=file)
# Out:
# <div id="3dmolviewer_17785194991337972"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_17785194991337972" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17785194991337972 = null;
# var warn = document.getElementById("3dmolwarning_17785194991337972");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17785194991337972 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17785194991337972"),{backgroundColor:"white"});
# viewer_17785194991337972.zoomTo();
# 	viewer_17785194991337972.addModel("4\nfrom xyz file\nC 0.0 0.0 0.0\nO 1.21 0.0 0.0\nH -0.599677 0.936997 0.0\nH -0.599677 -0.936997 0.0\n","xyz");
# 	viewer_17785194991337972.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_17785194991337972.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 2.3424300516479972, "y": 2.3424300516479972, "z": 2.3424300516479972}, "radius": 0.08, "color": "red", "mid": 0.7});
# 	viewer_17785194991337972.addLabel("|\u03bc| = 2.342 D",{"position": {"x": 3.3424300516479972, "y": 3.3424300516479972, "z": 3.3424300516479972}, "backgroundColor": "white", "fontColor": "black"});
# 	viewer_17785194991337972.setBackgroundColor("0xeeeeee");
# 	viewer_17785194991337972.zoomTo();
# 	viewer_17785194991337972.spin(true);
# viewer_17785194991337972.render();
# });
# </script>
# <div id="3dmolviewer_17785194991394649"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_17785194991394649" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17785194991394649 = null;
# var warn = document.getElementById("3dmolwarning_17785194991394649");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17785194991394649 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17785194991394649"),{backgroundColor:"white"});
# viewer_17785194991394649.zoomTo();
# 	viewer_17785194991394649.addModel("2\nfrom xyz file\nH 0.0 0.0 -0.637275\nCl 0.0 0.0 0.637275\n","xyz");
# 	viewer_17785194991394649.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_17785194991394649.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.24077505696479917, "y": 0.24077505696479917, "z": 0.24077505696479917}, "radius": 0.08, "color": "red", "mid": 0.7});
# 	viewer_17785194991394649.addLabel("|\u03bc| = 0.241 D",{"position": {"x": 1.2407750569647993, "y": 1.2407750569647993, "z": 1.2407750569647993}, "backgroundColor": "white", "fontColor": "black"});
# 	viewer_17785194991394649.setBackgroundColor("0xeeeeee");
# 	viewer_17785194991394649.zoomTo();
# 	viewer_17785194991394649.spin(true);
# viewer_17785194991394649.render();
# });
# </script>
# <div id="3dmolviewer_177851949914261"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_177851949914261" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_177851949914261 = null;
# var warn = document.getElementById("3dmolwarning_177851949914261");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_177851949914261 = $3Dmol.createViewer(document.getElementById("3dmolviewer_177851949914261"),{backgroundColor:"white"});
# viewer_177851949914261.zoomTo();
# 	viewer_177851949914261.addModel("6\nfrom xyz file\nC 0.0 0.0 0.0\nO 1.429 0.0 0.0\nH -0.543 0.935 0.0\nH -0.543 -0.4675 0.809526\nH -0.543 -0.4675 -0.809526\nH 1.82 0.0 0.89\n","xyz");
# 	viewer_177851949914261.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_177851949914261.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 4.204440968403004, "y": 4.204440968403004, "z": 4.204440968403004}, "radius": 0.08, "color": "red", "mid": 0.7});
# 	viewer_177851949914261.addLabel("|\u03bc| = 4.204 D",{"position": {"x": 5.204440968403004, "y": 5.204440968403004, "z": 5.204440968403004}, "backgroundColor": "white", "fontColor": "black"});
# 	viewer_177851949914261.setBackgroundColor("0xeeeeee");
# 	viewer_177851949914261.zoomTo();
# 	viewer_177851949914261.spin(true);
# viewer_177851949914261.render();
# });
# </script>
# <div id="3dmolviewer_17785194991453893"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_17785194991453893" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17785194991453893 = null;
# var warn = document.getElementById("3dmolwarning_17785194991453893");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17785194991453893 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17785194991453893"),{backgroundColor:"white"});
# viewer_17785194991453893.zoomTo();
# 	viewer_17785194991453893.addModel("3\nfrom xyz file\nO 0.0 0.0 0.0\nH 0.758602 0.0 0.504284\nH -0.758602 0.0 0.504284\n","xyz");
# 	viewer_17785194991453893.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_17785194991453893.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.4501373567313915, "y": 0.4501373567313915, "z": 0.4501373567313915}, "radius": 0.08, "color": "red", "mid": 0.7});
# 	viewer_17785194991453893.addLabel("|\u03bc| = 0.450 D",{"position": {"x": 1.4501373567313915, "y": 1.4501373567313915, "z": 1.4501373567313915}, "backgroundColor": "white", "fontColor": "black"});
# 	viewer_17785194991453893.setBackgroundColor("0xeeeeee");
# 	viewer_17785194991453893.zoomTo();
# 	viewer_17785194991453893.spin(true);
# viewer_17785194991453893.render();
# });
# </script>
# <div id="3dmolviewer_1778519499149891"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_1778519499149891" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1778519499149891 = null;
# var warn = document.getElementById("3dmolwarning_1778519499149891");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1778519499149891 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1778519499149891"),{backgroundColor:"white"});
# viewer_1778519499149891.zoomTo();
# 	viewer_1778519499149891.addModel("7\nfrom xyz file\nC -0.748 0.0 0.0\nC 0.748 0.0 0.0\nO 1.508 1.047 0.0\nH -1.129 -0.513 0.889\nH -1.129 -0.513 -0.889\nH -1.129 1.026 0.0\nH 1.14 -1.0 0.0\n","xyz");
# 	viewer_1778519499149891.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_1778519499149891.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 8.203976697010367, "y": 8.203976697010367, "z": 8.203976697010367}, "radius": 0.08, "color": "red", "mid": 0.7});
# 	viewer_1778519499149891.addLabel("|\u03bc| = 8.204 D",{"position": {"x": 9.203976697010367, "y": 9.203976697010367, "z": 9.203976697010367}, "backgroundColor": "white", "fontColor": "black"});
# 	viewer_1778519499149891.setBackgroundColor("0xeeeeee");
# 	viewer_1778519499149891.zoomTo();
# 	viewer_1778519499149891.spin(true);
# viewer_1778519499149891.render();
# });
# </script>
# <div id="3dmolviewer_17785194991516464"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_17785194991516464" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17785194991516464 = null;
# var warn = document.getElementById("3dmolwarning_17785194991516464");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17785194991516464 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17785194991516464"),{backgroundColor:"white"});
# viewer_17785194991516464.zoomTo();
# 	viewer_17785194991516464.addModel("4\nfrom xyz file\nN 0.0 0.0 0.116489\nH 0.0 0.939731 -0.271808\nH 0.813831 -0.469865 -0.271808\nH -0.813831 -0.469865 -0.271808\n","xyz");
# 	viewer_17785194991516464.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_17785194991516464.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.5416157908763597, "y": 0.5416157908763597, "z": 0.5416157908763597}, "radius": 0.08, "color": "red", "mid": 0.7});
# 	viewer_17785194991516464.addLabel("|\u03bc| = 0.542 D",{"position": {"x": 1.5416157908763597, "y": 1.5416157908763597, "z": 1.5416157908763597}, "backgroundColor": "white", "fontColor": "black"});
# 	viewer_17785194991516464.setBackgroundColor("0xeeeeee");
# 	viewer_17785194991516464.zoomTo();
# 	viewer_17785194991516464.spin(true);
# viewer_17785194991516464.render();
# });
# </script>
# <div id="3dmolviewer_1778519499153041"  style="position: relative; width: 700px; height: 500px;">
#         <p id="3dmolwarning_1778519499153041" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_1778519499153041 = null;
# var warn = document.getElementById("3dmolwarning_1778519499153041");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1778519499153041 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1778519499153041"),{backgroundColor:"white"});
# viewer_1778519499153041.zoomTo();
# 	viewer_1778519499153041.addModel("2\nfrom xyz file\nH 0.0 0.0 -0.3707\nH 0.0 0.0 0.3707\n","xyz");
# 	viewer_1778519499153041.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_1778519499153041.addArrow({"start": {"x": 0.0, "y": 0.0, "z": 0.0}, "end": {"x": 0.0, "y": 0.0, "z": 0.0}, "radius": 0.08, "color": "red", "mid": 0.7});
# 	viewer_1778519499153041.addLabel("|\u03bc| = 0.000 D",{"position": {"x": 1.0, "y": 1.0, "z": 1.0}, "backgroundColor": "white", "fontColor": "black"});
# 	viewer_1778519499153041.setBackgroundColor("0xeeeeee");
# 	viewer_1778519499153041.zoomTo();
# 	viewer_1778519499153041.spin(true);
# viewer_1778519499153041.render();
# });
# </script>
